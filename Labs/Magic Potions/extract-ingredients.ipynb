# %%
# pip install beautifulsoup4

# Scrape a list of potions

import requests
from bs4 import BeautifulSoup

def removeCitations(tag):
    for sup in tag.find_all('sup'):
            sup.extract()


def extractList(html):
    tab_elements = html.find('div', class_='mw-parser-output').find_all('ul', recursive=False )

    listItems=[]
    for tab in tab_elements:
        items=tab.css.select("li")
        for item in items:
            removeCitations(item)
            link = item.find('a')
            if( link ):
                description = item.get_text().replace(link.text, '').replace('-', '').strip()
                listItems.append({'name':link.text, 'link': link["href"].replace(baseUrl, ''), 'description':  description if len(description)>0 else '' })

    return listItems

baseUrl = "https://harrypotter.fandom.com"
ingredientsUrl = "/wiki/List_of_potion_ingredients"

page = requests.get(baseUrl+ingredientsUrl)
soup = BeautifulSoup(page.content, "html.parser")

ingredients=extractList(soup)

print("-- Ingredients --")
for x in range(len(ingredients)):
    print(ingredients[x])
# Out:
# -- Ingredients --
# {'name': 'Abraxan hair', 'link': '/wiki/Abraxan_hair', 'description': 'The hair of an Abraxan, used in Strong Exstimulo Potion.'}
# {'name': 'Aconite', 'link': '/wiki/Aconite', 'description': '(Wolfsbane or Monkshhod)  Used in the Wolfsbane Potion and the Wideye Potion.'}
# {'name': 'Acromantula venom', 'link': '/wiki/Acromantula_venom', 'description': 'Venom of the Acromantula spider: because of its rarity, it can sell for about one hundred Galleons a pint, and is an ingredient in the Armadillo Bile Mixture.'}
# {'name': "Adder's Fork", 'link': '/wiki/Adder%27s_Fork', 'description': 'The tongue of an Adder snake, unknown use and effect.'}
# {'name': 'African Red Pepper', 'link': '/wiki/African_Red_Pepper', 'description': 'Used in Piquant Toothpaste and Dentifricium Mouthwash.'}
# {'name': 'African Sea Salt', 'link': '/wiki/African_Sea_Salt', 'description': 'Used in Draught of Living Death.'}
# {'name': 'Agrippa', 'link': '/wiki/Agrippa', 'description': 'Unknown usage and effect.'}
# {'name': 'Alcohol', 'link': '/wiki/Alcohol', 'description': 'Ethanol, used in Elixir 7 and Pepperup Elixir.'}
# {'name': 'Alihotsy', 'link': '/wiki/Alihotsy', 'description': 'Used in the Laughing Potion and  Draught; the leaves cause uncontrollable laughter.'}
# {'name': "Angel's Trumpet", 'link': '/wiki/Angel%27s_Trumpet', 'description': 'is used as an ingredient in  Draught and the Tonic for Trace Detection, and is a highly poisonous plant.'}
# {'name': 'Anjelica', 'link': '/wiki/Anjelica', 'description': 'Magical herb with unknown effects and uses.'}
# {'name': 'Antimony', 'link': '/wiki/Antimony', 'description': 'No known usage or effect, but it is also used in its molten form.'}
# {'name': 'Armadillo bile', 'link': '/wiki/Armadillo_bile', 'description': 'Used in the WitSharpening Potion.'}
# {'name': 'Armotentia', 'link': '/wiki/Armotentia', 'description': 'The main component in the Armadillo Bile Mixture.'}
# {'name': 'Arnica', 'link': '/wiki/Arnica', 'description': 'Poisonous plant, used in the Syrup of this plant, an ingredient itself .'}
# {'name': 'Asian Dragon Hair', 'link': '/wiki/Asian_Dragon_Hair', 'description': "Used in Sleekeazy's Hair Potion"}
# {'name': 'Ashwinder egg', 'link': '/wiki/Ashwinder_egg', 'description': 'The eggs of an Ashwinder are used in Love Potions, Felix Felicis, Edurus Potions, and as an antidote to ague.'}
# {'name': 'Asphodel', 'link': '/wiki/Asphodel', 'description': 'The powdered roots of  are used in the Draught of Living Death and the Wiggenweld Potion.'}
# {'name': 'Avocado', 'link': '/wiki/Avocado', 'description': 'The skin of this fruit is used in Rat Spleen Mixture.'}
# {'name': 'Balm', 'link': '/wiki/Balm', 'description': 'Used in the The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Banana', 'link': '/wiki/Banana', 'description': 'Used in the Ageing Potion.'}
# {'name': 'Baneberry', 'link': '/wiki/Baneberry', 'description': 'Poisonous plant; used in the  Potion and the Tonic for Trace Detection.'}
# {'name': 'Bat spleen', 'link': '/wiki/Bat_spleen', 'description': 'Used in the Swelling Solution.'}
# {'name': 'Bat wing', 'link': '/wiki/Bat_wing', 'description': 'Used in the corrosive Armadillo Bile Mixture'}
# {'name': 'Beetle Eye', 'link': '/wiki/Beetle_Eye', 'description': 'The eyes of Beetles, Common ingredient.'}
# {'name': 'Belladonna', 'link': '/wiki/Belladonna', 'description': "Fluids are used in part of a standard potion makingkit. Believed to be a key ingredient in witches' flying ointment."}
# {'name': 'Betony', 'link': '/wiki/Betony', 'description': 'Used in the The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Bezoar', 'link': '/wiki/Bezoar', 'description': 'Acts as an antidote to most poisons, with the exception of Basilisk venom.'}
# {'name': 'Bicorn Horn', 'link': '/wiki/Horn_of_Bicorn', 'description': 'Powdered horns are used in Polyjuice Potion.'}
# {'name': 'Billywig sting', 'link': '/wiki/Billywig_sting', 'description': 'Has the ability to make a person float. Used in a variety of potions, including Antidote to Uncommon Poisons and the Wideye Potion.'}
# {'name': 'Billywig Sting Slime', 'link': '/wiki/Billywig_sting_slime', 'description': 'Has curative properties. Used in the Wiggenweld Potion.'}
# {'name': 'Billywig wings', 'link': '/wiki/Billywig_wings', 'description': 'Used in the Laughing Potion'}
# {'name': 'Bitter root', 'link': '/wiki/Bitter_root', 'description': 'Used in the Burning Bitterroot Balm.'}
# {'name': 'Blatta Pulvereus', 'link': '/wiki/Blatta_Pulvereus', 'description': 'Unknown origin and effect, presumably crushed insects.'}
# {'name': "Blind-worm's Sting", 'link': '/wiki/Blind-worm%27s_Sting', 'description': 'The sting of a Blindworm, unknown effect and usage.'}
# {'name': 'Blood', 'link': '/wiki/Blood', 'description': "Properties depend on the source. Unicorn blood can keep a person alive, while Re'em blood gives the drinker immense strength for a short time.  of a foe is used in the Dark Regeneration potion"}
# {'name': 'Bloodroot', 'link': '/wiki/Bloodroot', 'description': 'Poisonous plant, which kills animal cells, used as the main ingredient in  Poison.'}
# {'name': 'Blowfly', 'link': '/wiki/Blowfly', 'description': 'Common name for flies, unknown usage and effect.'}
# {'name': 'Bone', 'link': '/wiki/Bone', 'description': 'Used in the Regeneration potion.'}
# {'name': 'Boom Berry', 'link': '/wiki/Boom_Berry', 'description': 'Restorative properties. Used in the Wiggenweld Potion.'}
# {'name': 'Boomslang', 'link': '/wiki/Boomslang', 'description': 'Venom is highly poisonous, but slow to act. Skin used a potion ingredient.'}
# {'name': 'Boomslang Skin', 'link': '/wiki/Boomslang_skin', 'description': 'An unusual ingredient used in Polyjuice Potion and Beautification Potion.'}
# {'name': 'Borage', 'link': '/wiki/Borage', 'description': 'Plant or herb with unknown effects and usage.'}
# {'name': 'Bouncing Bulb', 'link': '/wiki/Bouncing_Bulb', 'description': 'Used in Pompion Potion.'}
# {'name': 'Bouncing Spider Juice', 'link': '/wiki/Bouncing_Spider_Juice', 'description': 'Standard ingredient in potion making.'}
# {'name': 'Bubotuber pus', 'link': '/wiki/Bubotuber_pus', 'description': 'Has acneridding qualities, as well as an ingredient in Fake protective potions and the Healing Potion.'}
# {'name': 'Bulbadox juice', 'link': '/wiki/Bulbadox_juice', 'description': 'Magical substance which can causes breakouts of boils, used in the brewing of the Tonic for Trace Detection.'}
# {'name': 'Bundimun Secretion', 'link': '/wiki/Bundimun_Secretion', 'description': 'Used in Doxycide, Bundimun Pomade and various cleaning products.'}
# {'name': 'Bursting mushroom', 'link': '/wiki/Bursting_mushroom', 'description': 'Used in the Fire Protection Potion.'}
# {'name': 'Butterscotch', 'link': '/wiki/Butterscotch', 'description': 'Sweet substance, used in the Dawdle Draught.'}
# {'name': 'Camphirated Spirit', 'link': '/wiki/Camphirated_Spirit', 'description': 'Used in The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Castor oil', 'link': '/wiki/Castor_oil', 'description': 'Used in the Love Potion Antidote.'}
# {'name': 'Cat Hair', 'link': '/wiki/Cat_hair', 'description': 'Standard potionmaking ingredient.'}
# {'name': 'Caterpillar', 'link': '/wiki/Caterpillar', 'description': 'Sliced caterpillars are used in the Shrinking Solution.'}
# {'name': 'Centaury', 'link': '/wiki/Centaury', 'description': 'Used in The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Cheese', 'link': '/wiki/Cheese', 'description': 'Used in Based Potions.'}
# {'name': 'Chicken Lips', 'link': '/wiki/Chicken_Lips', 'description': 'The lips of a chicken, unknown effects and usage.'}
# {'name': 'Chinese Chomping Cabbage', 'link': '/wiki/Chinese_Chomping_Cabbage', 'description': 'Magical plant. Used in the SkeleGro Potion.'}
# {'name': 'Chizpurfle Carapace', 'link': '/wiki/Chizpurfle_carapace', 'description': 'Used in the Antidote to Uncommon Poisons.'}
# {'name': 'Chizpurfle fang', 'link': '/wiki/Chizpurfle_fang', 'description': 'Used in the Wiggenweld Potion.'}
# {'name': 'Cinnamon', 'link': '/wiki/Cinnamon', 'description': 'Common spice, standard potionmaking ingredient.'}
# {'name': 'Cockroach', 'link': '/wiki/Cockroach', 'description': 'Small brown insect, unknown effect and usage.'}
# {'name': 'Corn starch', 'link': '/wiki/Corn_starch', 'description': 'Used in a fake version of panacea.'}
# {'name': 'Cowbane', 'link': '/wiki/Cowbane', 'description': 'Poisonous plant, used in Doxycide and Shrinking Solution.'}
# {'name': 'Crocodile Heart', 'link': '/wiki/Crocodile_heart', 'description': 'Unknown effect and usage.'}
# {'name': 'Daisy', 'link': '/wiki/Daisy', 'description': 'Its roots are used in the Shrinking Solution.'}
# {'name': 'Dandelion root', 'link': '/wiki/Dandelion_root', 'description': 'Standard potionmaking ingredient.'}
# {'name': 'Dandruff', 'link': '/wiki/Dandruff', 'description': 'Optional ingredient for the Polyjuice Potion.'}
# {'name': 'Deadlyius', 'link': '/wiki/Deadlyius', 'description': 'Unknown effect. Most likely a poisonous fungi.'}
# {'name': 'Death-Cap', 'link': '/wiki/Death-Cap', 'description': 'Extremely Poisonous mushroom. Used in the  Draught.'}
# {'name': 'Dittany', 'link': '/wiki/Dittany', 'description': 'Powerful healing herb. Promotes skin growth, to the point of making a fresh wound seem several days old. An ingredient in the Wiggenweld Potion and Mixture of powdered silver and dittany, the latter of which is used to cure Werewolf bites, along with the Healing Potion.'}
# {'name': 'Doxy egg', 'link': '/wiki/Doxy_egg', 'description': 'Highly poisonous egg of the Doxy, used in the Girding Potion.'}
# {'name': 'Dragon blood', 'link': '/wiki/Dragon_blood', 'description': 'Has a number of properties. May be used as an oven cleaner, spot remover, a cure for verruca and potion ingredient.'}
# {'name': 'Dragon claw', 'link': '/wiki/Dragon_claw', 'description': "When powdered and eaten, gives the consumer a 'brain boost', as well as ingredient in Tolipan Blemish Blitzer."}
# {'name': 'Dragon Claw Ooze', 'link': '/wiki/Dragon_Claw_Ooze', 'description': 'Unknown effect and usage.'}
# {'name': 'Dragon dung', 'link': '/wiki/Dragon_dung', 'description': 'Used as a fertiliser, particularly the DragonDung Fertiliser.'}
# {'name': 'Dragon horn', 'link': '/wiki/Dragon_horn', 'description': 'Common ingredient. Used in the FireBreathing Potion.'}
# {'name': 'Dragon liver', 'link': '/wiki/Dragon_liver', 'description': 'Liver of a dragon, used in the making of the Healing Potion.'}
# {'name': 'Dragonfly thorax', 'link': '/wiki/Dragonfly_thorax', 'description': 'When toasted, can be used in the Girding Potion and the DragonDung Fertiliser.'}
# {'name': 'Eagle Owl Feather', 'link': '/wiki/Eagle_owl_feather', 'description': 'Used in the Dragon Tonic.'}
# {'name': 'Eel eye', 'link': '/wiki/Eel_eye', 'description': 'Used in the Bulgeye Potion.'}
# {'name': 'Erumpent horn', 'link': '/wiki/Erumpent_horn', 'description': 'Powerful magical properties. Contains a deadly fluid that causes whatever it is injected into to explode. Used in the Tonic for Trace Detection'}
# {'name': 'Erumpent tail', 'link': '/wiki/Erumpent_tail', 'description': 'Unknown effect and usage.'}
# {'name': 'Essence of comfrey', 'link': '/wiki/Essence_of_comfrey', 'description': 'Organic oil, unknown effect and usage.'}
# {'name': 'Essence of Daisyroot', 'link': '/wiki/Essence_of_Daisyroot', 'description': 'Unknown effect and usage.'}
# {'name': 'Exploding Fluid', 'link': '/wiki/Exploding_Fluid', 'description': 'Gives the Erumpent Horn its explosive quality.'}
# {'name': 'Exploding Ginger Eyelash', 'link': '/wiki/Exploding_Ginger_Eyelash', 'description': 'Unknown effect. Used in a standard potionmaking kit.'}
# {'name': 'Eye of Newt', 'link': '/wiki/Eye_of_Newt', 'description': 'Unknown effect and usage.'}
# {'name': 'Eyeball', 'link': '/wiki/Eyeball', 'description': 'Unknown effect and usage.'}
# {'name': 'Fairy Wing', 'link': '/wiki/Fairy_wings', 'description': 'Rare ingredient, as fairies are difficult to capture. Found in the Girding Potion and Beautification Potion.'}
# {'name': 'Fanged Geranium', 'link': '/wiki/Fanged_Geranium', 'description': 'Fangs used as potion ingredients.'}
# {'name': 'Fillet of a Fenny Snake', 'link': '/wiki/Fillet_of_a_Fenny_Snake', 'description': 'Unknown effect.'}
# {'name': 'Fire', 'link': '/wiki/Fire', 'description': 'Used in the heating and brewing of potions.'}
# {'name': 'Firefly', 'link': '/wiki/Firefly', 'description': 'Small flying insects, unknown effect and usage.'}
# {'name': 'Fire Seed', 'link': '/wiki/Fire_Seed', 'description': 'Seed of the  Bush, maintains high temperatures, used in the FireBreathing Potion and Antidote to Uncommon Poisons.'}
# {'name': 'Flabberghasted Leech', 'link': '/wiki/Flabberghasted_leech', 'description': 'Unknown effect.'}
# {'name': 'Flesh', 'link': '/wiki/Flesh', 'description': 'The flesh of living beings, including humans  used in the Regeneration Potion that aided the Return of the Dark Lord.'}
# {'name': 'Flitterby', 'link': '/wiki/Flitterby', 'description': 'Moths used in potions.'}
# {'name': 'Flobberworm Mucus', 'link': '/wiki/Flobberworm_Mucus', 'description': 'Mucus of the Flobberworm, used as a common thickener in potions. A vital ingredient in the Wiggenweld Potion, Cure for Boils, Herbicide Potion and Sleeping Draught.'}
# {'name': 'Flower head', 'link': '/wiki/Flower_head', 'description': 'Unknown effect and usage.'}
# {'name': 'Fluxweed', 'link': '/wiki/Fluxweed', 'description': 'Known for its healing properties. Used in the Polyjuice Potion if picked at the full moon.'}
# {'name': 'Flying Seahorses', 'link': '/wiki/Flying_Seahorse', 'description': 'Used in the Girding Potion'}
# {'name': 'Foxglove', 'link': '/wiki/Foxglove', 'description': 'Poisonous plant, used in the Pompion Potion.'}
# {'name': 'Frog', 'link': '/wiki/Frog', 'description': 'Small green amphibians, parts used as potion ingredients, such as the  Parts Mixture.'}
# {'name': 'Frog brain', 'link': '/wiki/Frog_brain', 'description': "The brain of a frog, used in Baruffio's Brain Elixir."}
# {'name': 'Galanthus Nivalis', 'link': '/wiki/Galanthus_Nivalis', 'description': 'Commonly known as Snowdrop, unknown effect.'}
# {'name': 'Giant Purple Toad Wart', 'link': '/wiki/Giant_Purple_Toad_wart', 'description': "Difficult to extract, given the toads' tendency to disappear. Used in the Dragon Tonic."}
# {'name': 'Ginger', 'link': '/wiki/Ginger', 'description': 'Root  Used in the WitSharpening Potion.'}
# {'name': 'Gomas Barbadensis', 'link': '/wiki/Gomas_Barbadensis', 'description': "Used in Sleekeazy's Hair Potion."}
# {'name': 'Goosegrass', 'link': '/wiki/Goosegrass', 'description': 'Used for skin ailments and scurvy. May produce a red dye.'}
# {'name': 'Granian hair', 'link': '/wiki/Granian_hair', 'description': 'Unknown effect.'}
# {'name': 'Graphorn horn', 'link': '/wiki/Graphorn_horn', 'description': 'The horn of the Graphorn, extremely expensive and an ingredient in the Antidote to Uncommon Poisons'}
# {'name': 'Gravy', 'link': '/wiki/Gravy', 'description': 'Used in Fake protective potions.'}
# {'name': 'Griffin Claw', 'link': '/wiki/Griffin_claw', 'description': 'When powdered, used in the Strengthening Solution.'}
# {'name': 'Gillyweed', 'link': '/wiki/Gillyweed', 'description': 'When ingested, allows the user to grow gills and webbing between their fingers and toes. Unknown usage in potionmaking.'}
# {'name': 'Gnat Heads', 'link': '/wiki/Gnat_Heads', 'description': 'Unknown effect.'}
# {'name': 'Gulf', 'link': '/wiki/Gulf', 'description': 'Unknown effect.'}
# {'name': 'Gurdyroot', 'link': '/wiki/Gurdyroot', 'description': 'Extract of  used in the Love Potion Antidote and Stamina Game.'}
# {'name': 'Haliwinkles', 'link': '/wiki/Haliwinkles', 'description': 'Unknown effect. Presumably a plant or animal.'}
# {'name': 'Hellebore', 'link': '/wiki/Hellebore', 'description': 'Poisonous plant, used in the Syrup of , a potion ingredient in itself.'}
# {'name': 'Hemlock', 'link': '/wiki/Hemlock', 'description': 'Poisonous plant, used in Doxycide.'}
# {'name': 'Herbaria', 'link': '/wiki/Herbaria', 'description': 'Unknown effect.'}
# {'name': 'Hermit crab shell', 'link': '/wiki/Hermit_crab_shell', 'description': 'Used in the Dawdle Draught.'}
# {'name': 'Honey', 'link': '/wiki/Honey', 'description': 'Used in water, in a variety of potions.'}
# {'name': 'Honeywater', 'link': '/wiki/Honeywater', 'description': 'Drops are used in the Wiggenweld Potion, while larger quantities are used in the Volubilis Potion and the Antidote to Common Poisons.'}
# {'name': 'Horklump juice', 'link': '/wiki/Horklump_juice', 'description': 'Used in a range of healing potions, including the Wiggenweld Potion, as well as the poisonous Herbicide Potion.'}
# {'name': 'Horned slug', 'link': '/wiki/Horned_slug', 'description': 'When stewed, used in the BoilCure Potion.'}
# {'name': 'Horned toad', 'link': '/wiki/Horned_toad', 'description': 'Unknown effect.'}
# {'name': 'Horse hair', 'link': '/wiki/Horse_hair', 'description': 'Unknown effect.'}
# {'name': 'Horseradish', 'link': '/wiki/Horseradish', 'description': 'Perennial plant; powdered ingredient in the Laughing Potion.'}
# {'name': "Howlet's Wing", 'link': '/wiki/Howlet%27s_Wing', 'description': 'Unknown effect.'}
# {'name': 'Iguana blood', 'link': '/wiki/Iguana_blood', 'description': 'The blood of an Iguana, unknown effect and usage.'}
# {'name': 'Infusion of Wormwood', 'link': '/wiki/Infusion_of_Wormwood', 'description': 'Used in Draught of Living Death, Elixir to Induce Euphoria, Shrinking Solution and Vitamix Potion.'}
# {'name': 'Jewelweed', 'link': '/wiki/Jewelweed', 'description': 'Plant, used in Fergus Fungal Budge.'}
# {'name': 'Jobberknoll feather', 'link': '/wiki/Jobberknoll_feather', 'description': 'Used in Truth Serums and Memory Potions.'}
# {'name': 'Kelp', 'link': '/wiki/Kelp', 'description': 'Used in common Fertiliser.'}
# {'name': 'Knarl quills', 'link': '/wiki/Knarl_quill', 'description': 'Used in the Laughing Potion.'}
# {'name': 'Kneazle hair', 'link': '/wiki/Kneazle_hair', 'description': 'The hair of the Kneazle is used in the Rat Spleen Mixture.'}
# {'name': 'Knotgrass', 'link': '/wiki/Knotgrass', 'description': 'Magical properties. Used in the Polyjuice Potion'}
# {'name': 'Lacewing Fly', 'link': '/wiki/Lacewing_fly', 'description': 'When stewed for 21 days, used in the Polyjuice Potion'}
# {'name': "Lady's Mantle", 'link': '/wiki/Lady%27s_Mantle', 'description': 'A plant with magical properties. Used in Beautification Potion.'}
# {'name': 'Lard', 'link': '/wiki/Lard', 'description': 'Used in a fake version of panacea.'}
# {'name': 'Lavender', 'link': '/wiki/Lavender', 'description': 'Flower with calming influence and pleasant smell, used in the FireBreathing Potion and the Sleeping Draught.'}
# {'name': 'Leech', 'link': '/wiki/Leech', 'description': 'Used in the Polyjuice Potion .'}
# {'name': 'Leech Juice', 'link': '/wiki/Leech_juice', 'description': 'Used in the Shrinking Solution.'}
# {'name': 'Left handed nazle powder', 'link': '/wiki/Left_handed_nazle_powder', 'description': 'Magical powder, unknown effect and usage.'}
# {'name': 'Lethe River Water', 'link': '/wiki/Lethe_River_Water', 'description': 'Used in Memory Potion.'}
# {'name': 'Lionfish', 'link': '/wiki/Lionfish', 'description': 'Venomous fish, spines used as potion ingredient, as well as an powdered ingredient in the poisonous Potion N. 07.'}
# {'name': 'Lionfish Spine', 'link': '/wiki/Spine_of_Lionfish', 'description': 'When crushed into powder or used whole, used in healing potions, including Wiggenweld Potion, and the Herbicide Potion'}
# {'name': 'Liquorice', 'link': '/wiki/Liquorice', 'description': 'roots used in Love Potion Antidote.'}
# {'name': 'Liver', 'link': '/wiki/Liver', 'description': 'Offal of humans and animals, used in potions.'}
# {'name': "Lizard's Leg", 'link': '/wiki/Lizard%27s_Leg', 'description': 'The leg of a lizard, unknown effect and usage.'}
# {'name': 'Lobalug Venom', 'link': '/wiki/Lobalug_venom', 'description': 'The venom of a Lobalug, unknown effect and usage.'}
# {'name': 'Lovage', 'link': '/wiki/Lovage', 'description': 'Used in the Confusing Concoction and Befuddlement Draught.'}
# {'name': 'Mackled Malaclaw tail', 'link': '/wiki/Mackled_Malaclaw_tail', 'description': 'Tail of a Mackled Malaclaw, unknown effect and usage.'}
# {'name': 'Mallowsweet', 'link': '/wiki/Mallowsweet', 'description': 'Magical herb with unknown effect and usage.'}
# {'name': 'Mandrake', 'link': '/wiki/Mandrake', 'description': '\ufeff  Used in the  Restorative Draught.'}
# {'name': 'Mandrake, stewed', 'link': '/wiki/Stewed_Mandrake', 'description': 'Used in the Mandrake Restorative Draught, Wiggenweld Potion, Oculus Potion and Volubilis Potion.'}
# {'name': 'Mandrake Root', 'link': '/wiki/Mandrake_Root', 'description': 'Used in the Pepperup Potion.'}
# {'name': 'Maw', 'link': '/wiki/Maw', 'description': 'Unknown origin and effect.'}
# {'name': 'Mercury and Mars', 'link': '/wiki/Mercury_and_Mars', 'description': 'Unknown usage, probably poisonous.'}
# {'name': 'Mistletoe Berry', 'link': '/wiki/Mistletoe_berry', 'description': 'Used in the Antidote in Common Poisons.'}
# {'name': 'Mint', 'link': '/wiki/Mint', 'description': 'Used in The Famous French Method for the Bite of a Mad Dog and the FireBreathing Potion.'}
# {'name': 'Moly', 'link': '/wiki/Moly', 'description': 'Used in the Wiggenweld Potion.'}
# {'name': 'Mongrel Dog', 'link': '/wiki/Mongrel_Dog', 'description': 'fur  Used in the Edurus Potion'}
# {'name': 'Moondew', 'link': '/wiki/Moondew', 'description': 'Used in the Wiggenweld Potion, Draught of Living Death and Antidote to Common Poisons.'}
# {'name': 'Moonseed', 'link': '/wiki/Moonseed', 'description': 'Used in the  Poison.'}
# {'name': 'Moonstone', 'link': '/wiki/Moonstone', 'description': 'Used in Draught of Peace, Love Potions, and Potion No. 86.'}
# {'name': 'Morning dew', 'link': '/wiki/Morning_dew', 'description': 'Used in the Beautification Potion.'}
# {'name': 'Motherwort', 'link': '/wiki/Motherwort', 'description': 'Used in The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Murtlap tentacle', 'link': '/wiki/Murtlap_tentacle', 'description': 'Used in Murtlap Essence and Felix Felicis.'}
# {'name': 'Mushroom', 'link': '/wiki/Mushroom', 'description': 'Various types of fungi can be used as potion ingredients.'}
# {'name': "Nagini's venom", 'link': '/wiki/Nagini%27s_venom', 'description': 'Used in the Rudimentary body potion.'}
# {'name': 'Neem oil', 'link': '/wiki/Neem_oil', 'description': 'Essential oil extracted from the seeds of the Neem tree, used in the Fergus Fungal Budge.'}
# {'name': 'Nettle', 'link': '/wiki/Nettle', 'description': 'Dried s in Cure for Boils.'}
# {'name': 'Newt', 'link': '/wiki/Newt', 'description': 'Eyes and spleen used as potion ingredients.'}
# {'name': 'Newt spleen', 'link': '/wiki/Newt_spleen', 'description': 'Used in the Ageing Potion.'}
# {'name': "Niffler's Fancy", 'link': '/wiki/Niffler%27s_Fancy', 'description': 'Used in the Potion of All Potential.'}
# {'name': 'Nightshade', 'link': '/wiki/Nightshade', 'description': 'Plants with unknown effect and usage.'}
# {'name': 'Nux Myristica', 'link': '/wiki/Nux_Myristica', 'description': 'Magical plant with unknown effects and usage.'}
# {'name': 'Occamy egg', 'link': '/wiki/Occamy_egg', 'description': 'Used in Occamy Egg Yolk Shampoo and Felix Felicis.'}
# {'name': 'Octopus Powder', 'link': '/wiki/Octopus_Powder', 'description': 'Used to strengthen potions.'}
# {'name': 'Onion juice', 'link': '/wiki/Onion_juice', 'description': 'Used in Fergus Fungal Budge.'}
# {'name': 'Peacock feather', 'link': '/wiki/Peacock_feather', 'description': 'Used in Dragon Tonic.'}
# {'name': 'Pearl Dust', 'link': '/wiki/Pearl_Dust', 'description': 'Used in Love Potions.'}
# {'name': 'Peppermint', 'link': '/wiki/Peppermint', 'description': 'Sprigs used in the Elixir to Induce Euphoria.'}
# {'name': 'Petroleum Jelly', 'link': '/wiki/Petroleum_Jelly', 'description': "Used in Sleekeazy's Hair Potion."}
# {'name': 'Pickled Slugs', 'link': '/wiki/Pickled_Slugs', 'description': 'Unknown effect and usage'}
# {'name': 'Plangentine', 'link': '/wiki/Plangentine', 'description': 'Unknown effect and usage.'}
# {'name': 'Plantain', 'link': '/wiki/Plantain', 'description': 'Used in The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Poison ivy', 'link': '/wiki/Poison_ivy', 'description': 'Poisonous plant, unknown usage.'}
# {'name': 'Polypody', 'link': '/wiki/Polypody', 'description': 'Used in The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Pomegranate juice', 'link': '/wiki/Pomegranate_juice', 'description': 'Unknown usage and effect.'}
# {'name': 'Pond Slime', 'link': '/wiki/Pond_Slime', 'description': 'Unknown usage and effect.'}
# {'name': 'Poppy head', 'link': '/wiki/Poppy_head', 'description': 'Unknown usage and effect.'}
# {'name': 'Powder of vipers-flesh', 'link': '/wiki/Powder_of_vipers-flesh', 'description': 'Used in The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Porcupine quill', 'link': '/wiki/Porcupine_quill', 'description': 'Used in the Cure for Boils, Elixir to Induce Euphoria, HairRaising Potion and Draught of Peace.'}
# {'name': "Pritcher's Porritch", 'link': '/wiki/Pritcher%27s_Porritch', 'description': 'Used in the Potion of All Potential.'}
# {'name': 'Ptolemy', 'link': '/wiki/Ptolemy_(potion_ingredient)', 'description': 'Blood red magical substance, unknown effect and usage.'}
# {'name': 'Puffer-fish', 'link': '/wiki/Puffer-fish', 'description': 'Used in SkeleGro.'}
# {'name': 'Puffer-fish Eyes', 'link': '/wiki/Puffer-fish_eyes', 'description': 'Eyes of Pufferfish, used in the Swelling Solution.'}
# {'name': 'Puffskein hair', 'link': '/wiki/Puffskein_hair', 'description': 'Hair of the Puffskein, used in the Laughing Potion.'}
# {'name': 'Pungous Onion', 'link': '/wiki/Pungous_Onion', 'description': 'Magical plant, used in the Cure for Boils.'}
# {'name': 'Pus', 'link': '/wiki/Pus', 'description': 'The pus of certain plants, such as Bubotubers, can be used as potion ingredients.'}
# {'name': 'Rat spleen', 'link': '/wiki/Rat_spleen', 'description': 'Used in Dragon dung Fertiliser, Shrinking Solution and the Rat Spleen Mixture.'}
# {'name': 'Rat tail', 'link': '/wiki/Rat_tail', 'description': 'Used in the HairRaising Potion.'}
# {'name': "Re'em blood", 'link': '/wiki/Re%27em_blood', 'description': 'Used in the Exstimulo Potion.'}
# {'name': 'Rose', 'link': '/wiki/Rose', 'description': 'Common garden plant, with many of its parts used in potionmaking.'}
# {'name': 'Rose Petals', 'link': '/wiki/Rose_Petal', 'description': 'Used in the Beautification Potion and Love Potions.'}
# {'name': 'Rose thorn', 'link': '/wiki/Rose_thorn', 'description': 'Used in Love Potions.'}
# {'name': 'Rose oil', 'link': '/wiki/Rose_oil', 'description': 'Essential oil of the Rose plant, unknown effect and usage.'}
# {'name': 'Rotten egg', 'link': '/wiki/Rotten_egg', 'description': 'Decomposed eggs, unknown effects and usage.'}
# {'name': 'Rue', 'link': '/wiki/Rue', 'description': 'Evergreen shrubs, with healing properties: essence used to recover from poisoning, as well as an ingredient in The Famous French Method for the Bite of a Mad Dog and Felix Felicis.'}
# {'name': 'Runespoor egg', 'link': '/wiki/Runespoor_egg', 'description': "Used in Baruffio's Brain Elixir."}
# {'name': "Russian's Dragon Nails", 'link': '/wiki/Russian%27s_Dragon_Nails', 'description': 'Unknown effects and usage.'}
# {'name': 'Sage', 'link': '/wiki/Sage', 'description': 'A herb, used in its powdered form in the Memory Potion.'}
# {'name': 'Sal Ammoniac', 'link': '/wiki/Sal_Ammoniac', 'description': 'Used in Panacea.'}
# {'name': 'Salamander blood', 'link': '/wiki/Salamander_blood', 'description': 'Used in the Strengthening Solution and Wiggenweld Potion.'}
# {'name': 'Salpeter', 'link': '/wiki/Salpeter', 'description': 'Magical substance with unknown properties and effects.'}
# {'name': 'Salt', 'link': '/wiki/Salt', 'description': 'Used in Panacea and in salt water.'}
# {'name': 'Saltpetre', 'link': '/wiki/Saltpetre', 'description': 'another term for Potassium nitrate, unknown effect and usage in potionmaking.'}
# {'name': 'Salt water', 'link': '/wiki/Salt_water', 'description': 'Used in the Treatment for scale rot.'}
# {'name': 'Sardine', 'link': '/wiki/Sardine', 'description': 'Fish, unknown usage and fish.'}
# {'name': 'Scale of Dragon', 'link': '/wiki/Scale_of_Dragon', 'description': 'Scale of a dragon, unknown effect.'}
# {'name': 'Scarab beetle', 'link': '/wiki/Scarab_beetle', 'description': 'Used in SkeleGro.'}
# {'name': 'Scurvy grass', 'link': '/wiki/Scurvy_grass', 'description': 'Used in Befuddlement Draught.'}
# {'name': 'Shrake spine', 'link': '/wiki/Shrake_spine', 'description': "Used in Zygmunt Budge's version of the Cure for Boils."}
# {'name': 'Shrivelfig', 'link': '/wiki/Shrivelfig', 'description': 'Used in Elixir to Induce Euphoria and Shrinking Solution.'}
# {'name': 'Silver', 'link': '/wiki/Silver', 'description': 'Used in the Mixture of powdered silver and dittany.'}
# {'name': 'Silverweed', 'link': '/wiki/Silverweed', 'description': 'Plant in the Rose family, unknown effect and usage.'}
# {'name': 'Sloth brain', 'link': '/wiki/Sloth_brain', 'description': 'Mucus used in Draught of Living Death and Dragon dung Fertiliser.'}
# {'name': 'Snake fang', 'link': '/wiki/Snake_fang', 'description': 'Used in Cure for Boils, Wideye Potion and Strength Potion.'}
# {'name': 'Snakeweed', 'link': '/wiki/Snakeweed', 'description': 'Magical plant, unknown effect.'}
# {'name': 'Sneezewort', 'link': '/wiki/Sneezewort', 'description': 'Poisonous plant, used in the Befuddlement Draught.'}
# {'name': 'Sopophorous bean', 'link': '/wiki/Sopophorous_bean', 'description': 'Used in the Draught of Living Death'}
# {'name': 'Sopophorous plant', 'link': '/wiki/Sopophorous_plant', 'description': 'Beans used as ingredients.'}
# {'name': 'Spiders', 'link': '/wiki/Spider', 'description': 'Small arachnids, used in various potions with different effects.'}
# {'name': 'Spirit of Myrrh', 'link': '/wiki/Spirit_of_Myrrh', 'description': 'Used in the The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Spleenwart', 'link': '/wiki/Spleenwart', 'description': 'Magical plant, unknown effect and usage.'}
# {'name': 'Squill', 'link': '/wiki/Squill', 'description': 'Bulb of plant used as an ingredient in itself.'}
# {'name': 'Squill bulb', 'link': '/wiki/Squill_bulb', 'description': 'Bulb of the Squill plant, used in Felix Felicis.'}
# {'name': "St John's-wort", 'link': '/wiki/St_John%27s-wort', 'description': 'Used in The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Staghorn', 'link': '/wiki/Staghorn', 'description': 'Fungi, unknown effects and usage.'}
# {'name': 'Standard Ingredient', 'link': '/wiki/Standard_Ingredient', 'description': 'Dried herbs used as ingredient in many potions.'}
# {'name': 'Star Grass', 'link': '/wiki/Star_Grass', 'description': 'Medicinal herb used in the  Salve.'}
# {'name': 'Starthistle', 'link': '/wiki/Starthistle', 'description': 'Magical plant, unknown effect and usage.'}
# {'name': 'Stench of the Dead', 'link': '/wiki/Stench_of_the_Dead', 'description': 'Essence of Inferius, used in Thunderbrew.'}
# {'name': 'Streeler shells', 'link': '/wiki/Streeler_shell', 'description': 'Highly poisonous shells of the Streeler, used in the brewing of Doxycide.'}
# {'name': 'Sulphur Vive', 'link': '/wiki/Sulphur_Vive', 'description': 'Used in the Panacea.'}
# {'name': 'Syrup of Arnica', 'link': '/wiki/Syrup_of_Arnica', 'description': 'Poisonous substance extracted from its plant, unknown effects and usage.'}
# {'name': 'Syrup of Hellebore', 'link': '/wiki/Syrup_of_Hellebore', 'description': 'Used in Draught of Peace, Volubilis Potion and Potion No. 86.'}
# {'name': 'Tar', 'link': '/wiki/Tar', 'description': 'Used in the Treatment for scale rot.'}
# {'name': 'Thaumatagoria', 'link': '/wiki/Thaumatagoria', 'description': 'Used in the Potion of All Potential.'}
# {'name': 'Thyme', 'link': '/wiki/Thyme', 'description': 'Tincture of  used in Felix Felicis.'}
# {'name': 'Tincture of Demiguise', 'link': '/wiki/Tincture_of_Demiguise', 'description': 'Substance extracted from Demiguises, unknown effect and usage.'}
# {'name': 'Toe of Frog', 'link': '/wiki/Toe_of_Frog', 'description': 'The toe of a frog, unknown effect and usage.'}
# {'name': 'Tongue of Dog', 'link': '/wiki/Tongue_of_Dog', 'description': 'The tongue of a dog, unknown effect and usage.'}
# {'name': 'Tooth of Wolf', 'link': '/wiki/Tooth_of_Wolf', 'description': 'The tooth of a wolf, unknown effect and usage.'}
# {'name': 'Tormentil', 'link': '/wiki/Tormentil', 'description': "Used in Zygmunt Budge's version of Doxycide."}
# {'name': 'Tubeworm', 'link': '/wiki/Tubeworm', 'description': 'Wormlike aquatic creatures, unknown effect and usage.'}
# {'name': 'Turtle', 'link': '/wiki/Turtle', 'description': 'Shell  Unknown effect and usage.'}
# {'name': 'Unicorn Blood', 'link': '/wiki/Unicorn_blood', 'description': 'Used in the Rudimentary body potion.'}
# {'name': 'Unicorn Hair', 'link': '/wiki/Unicorn_hair', 'description': 'Used in the Beautification Potion'}
# {'name': 'Unicorn Horn', 'link': '/wiki/Unicorn_horn', 'description': 'Used in the Antidote to Common Poisons, Draught of Peace and the Wiggenweld Potion.'}
# {'name': 'Urine', 'link': '/wiki/Urine', 'description': 'Used in Panacea'}
# {'name': 'Valerian', 'link': '/wiki/Valerian', 'description': 'Plant used in Forgetfulness Potion, Sleeping Draught and FireBreathing Potion.'}
# {'name': 'Valerian root', 'link': '/wiki/Valerian_root', 'description': 'Root of plant used in Draught of Peace and Draught of Living Death.'}
# {'name': 'Venomous Tentacula', 'link': '/wiki/Venomous_Tentacula', 'description': 'Poisonous and dangerous plant; essence of  used in the poisonous Potion N. 07, as well as leaves used as ingredients.'}
# {'name': 'Venomous Tentacula leaf', 'link': '/wiki/Venomous_Tentacula_leaf', 'description': 'Leaves from the poisonous plant; unknown effect and usage but highly valuable on the market.'}
# {'name': 'Vervain', 'link': '/wiki/Vervain', 'description': 'Medicinal plant used in The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Vervain infusion', 'link': '/wiki/Vervain_infusion', 'description': 'Preparation of Vervain, with healing properties.'}
# {'name': 'Vinegar', 'link': '/wiki/Vinegar', 'description': 'Used in Panacea.'}
# {'name': 'Wartcap powder', 'link': '/wiki/Wartcap_powder', 'description': 'Used in the Fire Protection Potion.'}
# {'name': 'Wartizome', 'link': '/wiki/Wartizome', 'description': 'Magical plant, unknown effect and usage.'}
# {'name': 'Water', 'link': '/wiki/Water', 'description': 'Used as standard liquid component of all potions.'}
# {'name': 'White spirit', 'link': '/wiki/White_spirit', 'description': 'Used in the Treatment for scale rot.'}
# {'name': 'White Wine', 'link': '/wiki/Wine', 'description': 'Used as the liquid component in The Famous French Method for the Bite of a Mad Dog.'}
# {'name': 'Wiggenbush', 'link': '/wiki/Wiggenbush', 'description': 'Plant with unknown effects and usage.'}
# {'name': 'Wiggenbush bark', 'link': '/wiki/Wiggenbush_bark', 'description': 'Bark of plant with unknown effects and usage.'}
# {'name': 'Wiggentree', 'link': '/wiki/Wiggentree', 'description': 'Protective plant, bark used as potion ingredient.'}
# {'name': 'Wiggentree bark', 'link': '/wiki/Wiggentree_bark', 'description': 'Used in the Wiggenweld Potion.'}
# {'name': "Witch's Ganglion", 'link': '/wiki/Witch%27s_Ganglion', 'description': 'Used in the Potion of All Potential.'}
# {'name': "Witches' Mummy", 'link': '/wiki/Witches%27_Mummy', 'description': 'Substance with unknown effect and usage.'}
# {'name': 'Woodlice Extract 63', 'link': '/wiki/Woodlice_Extract_63', 'description': 'Substance with unknown effect and usage.'}
# {'name': 'Wood louse', 'link': '/wiki/Wood_louse', 'description': 'Small insects with unknown effect and usage.'}
# {'name': 'Wool of Bat', 'link': '/wiki/Wool_of_Bat', 'description': 'Unknown effect and usage.'}
# {'name': 'Wormwood', 'link': '/wiki/Wormwood', 'description': 'Bitter herb, essence and infusion of this plant used as common potion ingredients, plant itself used in Healing Potion.'}
# {'name': 'Wormwood Essence', 'link': '/wiki/Wormwood_Essence', 'description': 'Unknown effect and usage.'}

# %%
# grab ingredient details
for item in ingredients:
    print(item['name'])
    page = requests.get(baseUrl+item['link'])
    html = BeautifulSoup(page.content, "html.parser")

    infoItems = html.find_all('div', class_='pi-item')

    for info in infoItems:
        removeCitations(info)
        propertyName=info['data-source']
        propertyValue=info.css.select_one('div.pi-data-value')

        valueList = propertyValue.css.select_one('ul')
        if( valueList ):
            values=[]
            for valueItem in valueList.find_all('li'):
                values.append(valueItem.get_text())
            item[propertyName]=values    
        else:
            item[propertyName]=propertyValue.get_text()

    content = html.find('div', class_='mw-parser-output')
    
    fullDescription = ''
    for elem in content.find_all(recursive=False):
        if( elem.name == 'p' or elem.name == 'b' or elem.name == 'a' ):
            if( elem.find().name == 'aside'): 
                continue

            removeCitations(elem)
            fullDescription += ' ' + elem.get_text().replace('\r', '').replace('\n',' ').strip()
        if( elem.name == 'h2' ):
            break
       
    descriptionHeader = html.find(id='Description')
    if( descriptionHeader ):
        for elem in descriptionHeader.find_all_next(recursive=False):
            if( elem.name == 'h2' ):
                break
            if( elem.name == 'p' ):
                removeCitations(elem)
                fullDescription += ' ' + elem.get_text().replace('\r', '').replace('\n',' ').strip()
    
    item['fullDescription'] = fullDescription.strip()



import json

SAVE_PATH = "data/ingredients.json"
with open(SAVE_PATH, 'w') as f:
    json.dump(ingredients, f)
# Out:
# Abraxan hair
# Aconite
# Acromantula venom
# Adder's Fork
# African Red Pepper
# African Sea Salt
# Agrippa
# Alcohol
# Alihotsy
# Angel's Trumpet
# Anjelica
# Antimony
# Armadillo bile
# Armotentia
# Arnica
# Asian Dragon Hair
# Ashwinder egg
# Asphodel
# Avocado
# Balm
# Banana
# Baneberry
# Bat spleen
# Bat wing
# Beetle Eye
# Belladonna
# Betony
# Bezoar
# Bicorn Horn
# Billywig sting
# Billywig Sting Slime
# Billywig wings
# Bitter root
# Blatta Pulvereus
# Blind-worm's Sting
# Blood
# Bloodroot
# Blowfly
# Bone
# Boom Berry
# Boomslang
# Boomslang Skin
# Borage
# Bouncing Bulb
# Bouncing Spider Juice
# Bubotuber pus
# Bulbadox juice
# Bundimun Secretion
# Bursting mushroom
# Butterscotch
# Camphirated Spirit
# Castor oil
# Cat Hair
# Caterpillar
# Centaury
# Cheese
# Chicken Lips
# Chinese Chomping Cabbage
# Chizpurfle Carapace
# Chizpurfle fang
# Cinnamon
# Cockroach
# Corn starch
# Cowbane
# Crocodile Heart
# Daisy
# Dandelion root
# Dandruff
# Deadlyius
# Death-Cap
# Dittany
# Doxy egg
# Dragon blood
# Dragon claw
# Dragon Claw Ooze
# Dragon dung
# Dragon horn
# Dragon liver
# Dragonfly thorax
# Eagle Owl Feather
# Eel eye
# Erumpent horn
# Erumpent tail
# Essence of comfrey
# Essence of Daisyroot
# Exploding Fluid
# Exploding Ginger Eyelash
# Eye of Newt
# Eyeball
# Fairy Wing
# Fanged Geranium
# Fillet of a Fenny Snake
# Fire
# Firefly
# Fire Seed
# Flabberghasted Leech
# Flesh
# Flitterby
# Flobberworm Mucus
# Flower head
# Fluxweed
# Flying Seahorses
# Foxglove
# Frog
# Frog brain
# Galanthus Nivalis
# Giant Purple Toad Wart
# Ginger
# Gomas Barbadensis
# Goosegrass
# Granian hair
# Graphorn horn
# Gravy
# Griffin Claw
# Gillyweed
# Gnat Heads
# Gulf
# Gurdyroot
# Haliwinkles
# Hellebore
# Hemlock
# Herbaria
# Hermit crab shell
# Honey
# Honeywater
# Horklump juice
# Horned slug
# Horned toad
# Horse hair
# Horseradish
# Howlet's Wing
# Iguana blood
# Infusion of Wormwood
# Jewelweed
# Jobberknoll feather
# Kelp
# Knarl quills
# Kneazle hair
# Knotgrass
# Lacewing Fly
# Lady's Mantle
# Lard
# Lavender
# Leech
# Leech Juice
# Left handed nazle powder
# Lethe River Water
# Lionfish
# Lionfish Spine
# Liquorice
# Liver
# Lizard's Leg
# Lobalug Venom
# Lovage
# Mackled Malaclaw tail
# Mallowsweet
# Mandrake
# Mandrake, stewed
# Mandrake Root
# Maw
# Mercury and Mars
# Mistletoe Berry
# Mint
# Moly
# Mongrel Dog
# Moondew
# Moonseed
# Moonstone
# Morning dew
# Motherwort
# Murtlap tentacle
# Mushroom
# Nagini's venom
# Neem oil
# Nettle
# Newt
# Newt spleen
# Niffler's Fancy
# Nightshade
# Nux Myristica
# Occamy egg
# Octopus Powder
# Onion juice
# Peacock feather
# Pearl Dust
# Peppermint
# Petroleum Jelly
# Pickled Slugs
# Plangentine
# Plantain
# Poison ivy
# Polypody
# Pomegranate juice
# Pond Slime
# Poppy head
# Powder of vipers-flesh
# Porcupine quill
# Pritcher's Porritch
# Ptolemy
# Puffer-fish
# Puffer-fish Eyes
# Puffskein hair
# Pungous Onion
# Pus
# Rat spleen
# Rat tail
# Re'em blood
# Rose
# Rose Petals
# Rose thorn
# Rose oil
# Rotten egg
# Rue
# Runespoor egg
# Russian's Dragon Nails
# Sage
# Sal Ammoniac
# Salamander blood
# Salpeter
# Salt
# Saltpetre
# Salt water
# Sardine
# Scale of Dragon
# Scarab beetle
# Scurvy grass
# Shrake spine
# Shrivelfig
# Silver
# Silverweed
# Sloth brain
# Snake fang
# Snakeweed
# Sneezewort
# Sopophorous bean
# Sopophorous plant
# Spiders
# Spirit of Myrrh
# Spleenwart
# Squill
# Squill bulb
# St John's-wort
# Staghorn
# Standard Ingredient
# Star Grass
# Starthistle
# Stench of the Dead
# Streeler shells
# Sulphur Vive
# Syrup of Arnica
# Syrup of Hellebore
# Tar
# Thaumatagoria
# Thyme
# Tincture of Demiguise
# Toe of Frog
# Tongue of Dog
# Tooth of Wolf
# Tormentil
# Tubeworm
# Turtle
# Unicorn Blood
# Unicorn Hair
# Unicorn Horn
# Urine
# Valerian
# Valerian root
# Venomous Tentacula
# Venomous Tentacula leaf
# Vervain
# Vervain infusion
# Vinegar
# Wartcap powder
# Wartizome
# Water
# White spirit
# White Wine
# Wiggenbush
# Wiggenbush bark
# Wiggentree
# Wiggentree bark
# Witch's Ganglion
# Witches' Mummy
# Woodlice Extract 63
# Wood louse
# Wool of Bat
# Wormwood
# Wormwood Essence
